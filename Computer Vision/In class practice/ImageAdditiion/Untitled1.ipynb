# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2.cvtColor(cv2.imread("left.jpg"), cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(cv2.imread("right.jpeg"), cv2.COLOR_BGR2GRAY)

# %%
img1 = img1[:280,:389]

# %%
img2.shape
# Out:
# (280, 389)

# %%
plt.imshow(np.hstack([img1,img2]),cmap="gray")

# %%
# sum of two images
img_sum = img1 * 0.4 + img2 * 0.6
plt.imshow(img_sum,cmap="gray")
